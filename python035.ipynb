# %% [markdown]
# โจทย์ที่ 1: หาค่าผลรวมของเลขที่หาร 3 ลงตัว ตั้งแต่ 1 - 30

# %%
sum = 0
for num in range(1, 31):
  if num % 3 == 0:
    sum += num

print("ผลรวมของเลขที่หารด้วย 3 ลงตัวตั้งแต่ 1-30 คือ:", sum)
# Out:
# ผลรวมของเลขที่หารด้วย 3 ลงตัวตั้งแต่ 1-30 คือ: 165

# %% [markdown]
# โจทย์ที่ 2: เขียนโปรแกรมเพื่อนับคำในประโยคที่กำหนด เช่น txt = "this is a book" นับได้ 4 คำ

# %%
txt = "this is a book"
word = txt.split()
num = len(word)

print("This is a book นับได้:", num)
# Out:
# This is a book นับได้: 4

# %% [markdown]
# โจทย์ที่ 3: เขียนโปรแกรมเพื่อหาค่าต่ำสุดและสูงสุดใน list เช่น mylist = [10, 5, 8, 2, 15] ค่าต่ำสุดคือ 2 ค่าสูงสุดคือ 15

# %%
mylist = [10, 5, 8, 2, 15]
#หาค่าต่ำสุด
min_value = min(mylist)
#หาค่าสูงสุด
max_value = max(mylist)
print("ค่าต่ำสุดคือ :",min_value)
print("ค่าสูงสุดคือ :",max_value)
# Out:
# ค่าต่ำสุดคือ : 2
# ค่าสูงสุดคือ : 15
